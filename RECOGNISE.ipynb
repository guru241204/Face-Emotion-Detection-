# %%
import urllib
import cv2
import numpy as np
from keras.models import load_model

classifier = cv2.CascadeClassifier(r"C:\Users\ASUS\OneDrive\Desktop\AI &ML PROJECT\haarcascade_frontalface_default (1) (1).xml")

model = load_model(r"C:\Users\ASUS\OneDrive\Desktop\AI &ML PROJECT\final_model.h5")

URL = 'http://192.0.0.4:8080/shot.jpg'

def get_pred_label(pred):
    labels = ['Shakti Subham', 'Sushree', 'rajesh']
    return labels[pred]

def preprocess(img):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img,(100,100))
    img = cv2.equalizeHist(img)
    img = img.reshape(1,100,100,1)
    img = img/255
    return img
    


ret = True
while ret:
    
    img_url = urllib.request.urlopen(URL)
    image = np.array(bytearray(img_url.read()),np.uint8)
    frame = cv2.imdecode(image,-1)
    
    faces = classifier.detectMultiScale(frame,1.5,5)
      
    for x,y,w,h in faces:
        face = frame[y:y+h,x:x+w]
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),5)
        cv2.putText(frame,get_pred_label(np.argmax(model.predict(preprocess(face)))),
                    (200,200),cv2.FONT_HERSHEY_COMPLEX,1,
                    (255,0,0),2)
        
    cv2.imshow("capture",frame)
    if cv2.waitKey(1)==ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 42
#      37     cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),5)
#      38     cv2.putText(frame,get_pred_label(np.argmax(model.predict(preprocess(face)))),
#      39                 (200,200),cv2.FONT_HERSHEY_COMPLEX,1,
#      40                 (255,0,0),2)
# ---> 42 cv2.imshow("capture",frame)
#      43 if cv2.waitKey(1)==ord('q'):
#      44     break
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
